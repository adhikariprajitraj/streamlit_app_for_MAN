# %%
import numpy as np
import pandas as pd
import seaborn

# %%
data = pd.read_csv('DMO scores.csv')

# %%
data.columns
# Out:
# Index(['S. No.', 'Symbol No.', 'Name of Students', 'Score', 'District',
#        'Venue'],
#       dtype='object')

# %%
seaborn.boxplot(data = data['Score'],orient='h', saturation=1, color ='red')
# Out:
# <AxesSubplot: >

# %%
normal_dist = seaborn.displot(data= data['Score'],color='green', kind='kde')

# %%
score = data['Score']

seaborn.histplot(score,stat='density',color='#44eecc')
# Out:
# <AxesSubplot: xlabel='Score', ylabel='Density'>

# %%
print(f"Mean {np.mean(score)}")
print(f'standard deviation: {np.std(score)}')
print(f'median: {np.median(score)}')
# Out:
# Mean 19.947008547008547
# standard deviation: 5.7899643895628214
# median: 20.0

# %%
np.count_nonzero(score)
# Out:
# 585

# %%
score.describe()
# Out:
# count    585.000000
# mean      19.947009
# std        5.794919
# min        5.000000
# 25%       16.000000
# 50%       20.000000
# 75%       24.000000
# max       36.000000
# Name: Score, dtype: float64

# %%
print(f'**Mode:**  {data["Score"].mode()[0]}')
# Out:
# **Mode:**  17

# %%
districts = set(data['District'])
districts
# Out:
# {'Dang', 'Kailali', 'Kathmandu', 'Kavre', 'Palpa', 'Pokhara', 'Surkhet'}

# %%
print(data['Name of Students'])
# Out:
# 0               Indra Adhikari
# 1                Suikar Lamsal
# 2                 Pranil Joshi
# 3              Aarohan Niroula
# 4      Shreyash Sharma Bastola
#                 ...
# 580              Success Kafle
# 581          Robesckey Dangol
# 582              Anuj Maharjan
# 583             Saral Maharjan
# 584            Nuniya Maharjan
# Name: Name of Students, Length: 585, dtype: object

# %%
"Indra Adhikari" in list(data['Name of Students'])
# Out:
# True

# %%
max(data['Score'])
# Out:
# 36

# %% [markdown]
# max_score = data['Score'].max()

# %%
data['Name of Students'].str.contains('Suikar Lamsal')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 580    False
# 581    False
# 582    False
# 583    False
# 584    False
# Name: Name of Students, Length: 585, dtype: bool

# %%
print("prajit aDhiKari".title())
# Out:
# Prajit Adhikari
